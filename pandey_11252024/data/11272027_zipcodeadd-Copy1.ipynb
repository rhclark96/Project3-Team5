# %% [markdown]
# # Importing and Cleaning of Data
# From CSV file back to a "cleaned" CSV

# %%
#Importing Libraries
import pandas as pd
from pathlib import Path 
import requests
import json
import time
import numpy as np
import re
from geopy.geocoders import Nominatim
from tqdm import tqdm

# %%
#Read CSV file into a Dataframe
vaccine_providers = Path("../Resources/Vaccines.gov__COVID-19_vaccinating_provider_locations_20241118.csv")
providers_df = pd.read_csv(vaccine_providers)
providers_df.head()

# %%
#Rename and reorganize columns of the DataFrame
renamed_df = providers_df.rename(columns={"loc_phone":"Phone Number", 
                                         "loc_name":"Location Name", 
                                         "loc_admin_street1":"Street Address",
                                         "loc_admin_city":"City", 
                                         "loc_admin_state":"State", 
                                         "loc_admin_zip":"Zip Code", 
                                         "web_address":"Website", 
                                         "insurance_accepted":"Insurance Accepted",
                                          "walkins_accepted": "Walk-Ins Accepted",
                                          "med_name":"Types of Vaccine", 
                                          "in_stock":"In Stock", 
                                          "quantity_last_updated":"Last Updated", 
                                          "latitude": "Latitude", 
                                          "longitude":"Longitude"})
vaccine_providers_df = renamed_df[["Location Name", 
                                   "Phone Number", 
                                   "Street Address", 
                                   "City", 
                                   "State", 
                                   "Zip Code",
                                  "Website",
                                  "Insurance Accepted",
                                  "Walk-Ins Accepted", 
                                  "Types of Vaccine",
                                  "In Stock",
                                  "Last Updated", 
                                  "Latitude", 
                                  "Longitude"]]

# %%
#Check data types
vaccine_providers_df.dtypes

# %%
#Convert all phone numbers to same format
#Convert phone numbers with a decimal to dashes
def convert_phone_number(phone):
    pattern = r"(\d{3})(\d{3})(\d{4})\.0"
    replacement = r"\1-\2-\3"
    return re.sub(pattern, replacement, phone)

# Apply the function to the 'Phone Number' column
vaccine_providers_df['Phone Number'] = vaccine_providers_df['Phone Number'].apply(convert_phone_number)

#Convert phone numbers from having (Areacode in parentheses) to 314-123-4567 format.
def convert_phone_number(phone):
    pattern = r"\((\d{3})\) (\d{3})-(\d{4})"
    replacement = r"\1-\2-\3"
    return re.sub(pattern, replacement, phone)

# Apply the function to the 'Phone Number' column
vaccine_providers_df['Phone Number'] = vaccine_providers_df['Phone Number'].apply(convert_phone_number)

#Convert phone numbers from 3141234567 to 314-123-4567 format.
def convert_phone_number(phone):
    pattern = r"(\d{3})(\d{3})(\d{4})"
    replacement = r"\1-\2-\3"
    return re.sub(pattern, replacement, phone)

# Apply the function to the 'Phone Number' column
vaccine_providers_df['Phone Number'] = vaccine_providers_df['Phone Number'].apply(convert_phone_number)

vaccine_providers_df.head()

# %%
#Clean all zip codes to be 5 digits only
#Fix the zipcode to have five digits
def fix_zipcode(zipcode):
    match = re.match(r'(\d{5})-\d{4}', zipcode)
    if match:
        return match.group(1)
vaccine_providers_df['Zip Code'] = vaccine_providers_df['Zip Code'].apply(fix_zipcode)
# Display the updated DataFrame
vaccine_providers_df

# %%
#Convert the insuracne and walk-ins columns to booleans
def convert_Insurance_to_boolean(value):
    if value in ['True', True]:
        return True
    else:
        return False
vaccine_providers_df['Insurance Accepted'] = vaccine_providers_df['Insurance Accepted'].apply(convert_Insurance_to_boolean)

def convert_Walk_Ins_to_boolean(value):
    if value in ['True', True]:
        return True
    else:
        return False
vaccine_providers_df['Walk-Ins Accepted'] = vaccine_providers_df['Walk-Ins Accepted'].apply(convert_Walk_Ins_to_boolean)

# %%
#Check data types for all columns
vaccine_providers_df.dtypes

# %%
#Save DataFrame to a csv
vaccine_providers_df.to_csv("Vaccine Providers.csv")

# %%
#Save DataFrame to a csv
vaccine_providers_df.to_json("providers.json")

# %%
# Check for NaN values
nan_count = vaccine_providers_df.isnull().sum()

# Display the count of NaN values for each column
print("Count of NaN values in each column:")
print(nan_count)

# To get the locations of NaN values
nan_locations = vaccine_providers_df.isnull()
print("\nLocations of NaN values:")
print(nan_locations)

# %%
zipcode_drop_df = vaccine_providers_df.drop(columns=['Zip Code'])
print(zipcode_drop_df)
# Out:
#                     Location Name  Phone Number                Street Address  \
# 0        CVS Pharmacy, Inc. #5340  504-737-6242          9643-B JEFFERSON HWY
# 1        CVS Pharmacy, Inc. #2113  215-836-1323         1600 WADSWORTH AVENUE
# 2       CVS Pharmacy, Inc. #16504  619-315-0016               2911 JAMACHA RD
# 3              Rite Aid #RA105255  253-851-6939     4818 POINT FOSDICK DR.,NW
# 4            Walmart Inc #10-1447  715-392-9520                3705 Tower Ave
# ...                           ...           ...                           ...
# 135780      SAV-ON PHARMACY #3739  215-942-4894               105 E STREET RD
# 135781         Rite Aid #RA101653  603-532-6955        14 PETERBOROUGH STREET
# 135782   CVS Pharmacy, Inc. #4378  540-989-6633           4400 BRAMBLETON AVE
# 135783         Rite Aid #RA101963  724-438-9799      262 CONNELLSVILLE STREET
# 135784        VONS PHARMACY #1962  951-695-7273  29530 RANCHO CALIFORNIA ROAD
#
#                         City State  \
# 0                RIVER RIDGE    LA
# 1               PHILADELPHIA    PA
# 2                   EL CAJON    CA
# 3                 GIG HARBOR    WA
# 4                   Superior    WI
# ...                      ...   ...
# 135780  Feasterville Trevose    PA
# 135781               JAFFREY    NH
# 135782               ROANOKE    VA
# 135783             UNIONTOWN    PA
# 135784              Temecula    CA
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135780      https://www.acmemarkets.com/vaccinations/home                True
# 135781                            https://www.riteaid.com                True
# 135782  https://www.cvs.com/store-locator/details-dire...                True
# 135783                            https://www.riteaid.com                True
# 135784             https://www.vons.com/vaccinations/home                True
#
#         Walk-Ins Accepted                                   Types of Vaccine  \
# 0                    True          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 1                    True  Pfizer-BioNTech, COVID-19 Vaccine, 10mcg/0.3 m...
# 2                    True  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# 3                   False  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# 4                    True  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# ...                   ...                                                ...
# 135780               True  Pfizer-BioNTech, COVID-19 Vaccine, 3mcg/0.3 mL...
# 135781              False          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 135782               True    Novavax, COVID-19 Vaccine, 5 mcg/0.5 mL, 5 dose
# 135783              False          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 135784               True    Novavax, COVID-19 Vaccine, 5 mcg/0.5 mL, 5 dose
#
#         In Stock Last Updated   Latitude   Longitude
# 0          False   2024-08-01  29.957522  -90.217062
# 1          False   2024-08-01  40.080415  -75.171958
# 2           True   2024-08-01  32.738217 -116.938327
# 3          False   2024-08-01  47.302477 -122.581456
# 4          False   2024-08-01  46.694518  -92.106958
# ...          ...          ...        ...         ...
# 135780     False   2024-08-01  40.147454  -74.999655
# 135781     False   2024-08-01  42.814691  -72.021353
# 135782     False   2024-08-01  37.224879  -80.011439
# 135783     False   2024-08-01  39.900490  -79.706902
# 135784     False   2024-08-01  33.505168 -117.147891
#
# [135785 rows x 13 columns]

# %%
nozipcode_latlng_dropna_df = zipcode_drop_df.dropna()

# Display the cleaned DataFrame
print("\nDataFrame after removing rows with null values:")
print(nozipcode_latlng_dropna_df)
# Out:
# DataFrame after removing rows with null values:
#                     Location Name  Phone Number                Street Address  \
# 0        CVS Pharmacy, Inc. #5340  504-737-6242          9643-B JEFFERSON HWY
# 1        CVS Pharmacy, Inc. #2113  215-836-1323         1600 WADSWORTH AVENUE
# 2       CVS Pharmacy, Inc. #16504  619-315-0016               2911 JAMACHA RD
# 3              Rite Aid #RA105255  253-851-6939     4818 POINT FOSDICK DR.,NW
# 4            Walmart Inc #10-1447  715-392-9520                3705 Tower Ave
# ...                           ...           ...                           ...
# 135780      SAV-ON PHARMACY #3739  215-942-4894               105 E STREET RD
# 135781         Rite Aid #RA101653  603-532-6955        14 PETERBOROUGH STREET
# 135782   CVS Pharmacy, Inc. #4378  540-989-6633           4400 BRAMBLETON AVE
# 135783         Rite Aid #RA101963  724-438-9799      262 CONNELLSVILLE STREET
# 135784        VONS PHARMACY #1962  951-695-7273  29530 RANCHO CALIFORNIA ROAD
#
#                         City State  \
# 0                RIVER RIDGE    LA
# 1               PHILADELPHIA    PA
# 2                   EL CAJON    CA
# 3                 GIG HARBOR    WA
# 4                   Superior    WI
# ...                      ...   ...
# 135780  Feasterville Trevose    PA
# 135781               JAFFREY    NH
# 135782               ROANOKE    VA
# 135783             UNIONTOWN    PA
# 135784              Temecula    CA
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135780      https://www.acmemarkets.com/vaccinations/home                True
# 135781                            https://www.riteaid.com                True
# 135782  https://www.cvs.com/store-locator/details-dire...                True
# 135783                            https://www.riteaid.com                True
# 135784             https://www.vons.com/vaccinations/home                True
#
#         Walk-Ins Accepted                                   Types of Vaccine  \
# 0                    True          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 1                    True  Pfizer-BioNTech, COVID-19 Vaccine, 10mcg/0.3 m...
# 2                    True  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# 3                   False  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# 4                    True  Pfizer-BioNTech, COMIRNATY, 30mcg/0.3 mL, syringe
# ...                   ...                                                ...
# 135780               True  Pfizer-BioNTech, COVID-19 Vaccine, 3mcg/0.3 mL...
# 135781              False          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 135782               True    Novavax, COVID-19 Vaccine, 5 mcg/0.5 mL, 5 dose
# 135783              False          Moderna, SPIKEVAX, 50 mcg/0.5 mL, syringe
# 135784               True    Novavax, COVID-19 Vaccine, 5 mcg/0.5 mL, 5 dose
#
#         In Stock Last Updated   Latitude   Longitude
# 0          False   2024-08-01  29.957522  -90.217062
# 1          False   2024-08-01  40.080415  -75.171958
# 2           True   2024-08-01  32.738217 -116.938327
# 3          False   2024-08-01  47.302477 -122.581456
# 4          False   2024-08-01  46.694518  -92.106958
# ...          ...          ...        ...         ...
# 135780     False   2024-08-01  40.147454  -74.999655
# 135781     False   2024-08-01  42.814691  -72.021353
# 135782     False   2024-08-01  37.224879  -80.011439
# 135783     False   2024-08-01  39.900490  -79.706902
# 135784     False   2024-08-01  33.505168 -117.147891
#
# [134709 rows x 13 columns]

# %%
#Save DataFrame to a csv
nozipcode_latlng_dropna_df.to_csv("nozipcode.csv")

# %%
dropvaccinetypes_df = nozipcode_latlng_dropna_df.drop(columns=['Types of Vaccine'])
print(dropvaccinetypes_df)
# Out:
#                     Location Name  Phone Number                Street Address  \
# 0        CVS Pharmacy, Inc. #5340  504-737-6242          9643-B JEFFERSON HWY
# 1        CVS Pharmacy, Inc. #2113  215-836-1323         1600 WADSWORTH AVENUE
# 2       CVS Pharmacy, Inc. #16504  619-315-0016               2911 JAMACHA RD
# 3              Rite Aid #RA105255  253-851-6939     4818 POINT FOSDICK DR.,NW
# 4            Walmart Inc #10-1447  715-392-9520                3705 Tower Ave
# ...                           ...           ...                           ...
# 135780      SAV-ON PHARMACY #3739  215-942-4894               105 E STREET RD
# 135781         Rite Aid #RA101653  603-532-6955        14 PETERBOROUGH STREET
# 135782   CVS Pharmacy, Inc. #4378  540-989-6633           4400 BRAMBLETON AVE
# 135783         Rite Aid #RA101963  724-438-9799      262 CONNELLSVILLE STREET
# 135784        VONS PHARMACY #1962  951-695-7273  29530 RANCHO CALIFORNIA ROAD
#
#                         City State  \
# 0                RIVER RIDGE    LA
# 1               PHILADELPHIA    PA
# 2                   EL CAJON    CA
# 3                 GIG HARBOR    WA
# 4                   Superior    WI
# ...                      ...   ...
# 135780  Feasterville Trevose    PA
# 135781               JAFFREY    NH
# 135782               ROANOKE    VA
# 135783             UNIONTOWN    PA
# 135784              Temecula    CA
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135780      https://www.acmemarkets.com/vaccinations/home                True
# 135781                            https://www.riteaid.com                True
# 135782  https://www.cvs.com/store-locator/details-dire...                True
# 135783                            https://www.riteaid.com                True
# 135784             https://www.vons.com/vaccinations/home                True
#
#         Walk-Ins Accepted  In Stock Last Updated   Latitude   Longitude
# 0                    True     False   2024-08-01  29.957522  -90.217062
# 1                    True     False   2024-08-01  40.080415  -75.171958
# 2                    True      True   2024-08-01  32.738217 -116.938327
# 3                   False     False   2024-08-01  47.302477 -122.581456
# 4                    True     False   2024-08-01  46.694518  -92.106958
# ...                   ...       ...          ...        ...         ...
# 135780               True     False   2024-08-01  40.147454  -74.999655
# 135781              False     False   2024-08-01  42.814691  -72.021353
# 135782               True     False   2024-08-01  37.224879  -80.011439
# 135783              False     False   2024-08-01  39.900490  -79.706902
# 135784               True     False   2024-08-01  33.505168 -117.147891
#
# [134709 rows x 12 columns]

# %%
dropvaccinetypes_df.head()
# Out:
#                Location Name  Phone Number             Street Address  \
# 0   CVS Pharmacy, Inc. #5340  504-737-6242       9643-B JEFFERSON HWY
# 1   CVS Pharmacy, Inc. #2113  215-836-1323      1600 WADSWORTH AVENUE
# 2  CVS Pharmacy, Inc. #16504  619-315-0016            2911 JAMACHA RD
# 3         Rite Aid #RA105255  253-851-6939  4818 POINT FOSDICK DR.,NW
# 4       Walmart Inc #10-1447  715-392-9520             3705 Tower Ave
#
#            City State                                            Website  \
# 0   RIVER RIDGE    LA  https://www.cvs.com/store-locator/details-dire...
# 1  PHILADELPHIA    PA  https://www.cvs.com/store-locator/details-dire...
# 2      EL CAJON    CA  https://www.cvs.com/store-locator/details-dire...
# 3    GIG HARBOR    WA                            https://www.riteaid.com
# 4      Superior    WI                 https://www.walmart.com/store/1447
#
#    Insurance Accepted  Walk-Ins Accepted  In Stock Last Updated   Latitude  \
# 0                True               True     False   2024-08-01  29.957522
# 1                True               True     False   2024-08-01  40.080415
# 2                True               True      True   2024-08-01  32.738217
# 3                True              False     False   2024-08-01  47.302477
# 4                True               True     False   2024-08-01  46.694518
#
#     Longitude
# 0  -90.217062
# 1  -75.171958
# 2 -116.938327
# 3 -122.581456
# 4  -92.106958

# %%
dropvaccinetypes1_df = dropvaccinetypes_df.dropna()
print(dropvaccinetypes1_df)
# Out:
#                     Location Name  Phone Number                Street Address  \
# 0        CVS Pharmacy, Inc. #5340  504-737-6242          9643-B JEFFERSON HWY
# 1        CVS Pharmacy, Inc. #2113  215-836-1323         1600 WADSWORTH AVENUE
# 2       CVS Pharmacy, Inc. #16504  619-315-0016               2911 JAMACHA RD
# 3              Rite Aid #RA105255  253-851-6939     4818 POINT FOSDICK DR.,NW
# 4            Walmart Inc #10-1447  715-392-9520                3705 Tower Ave
# ...                           ...           ...                           ...
# 135780      SAV-ON PHARMACY #3739  215-942-4894               105 E STREET RD
# 135781         Rite Aid #RA101653  603-532-6955        14 PETERBOROUGH STREET
# 135782   CVS Pharmacy, Inc. #4378  540-989-6633           4400 BRAMBLETON AVE
# 135783         Rite Aid #RA101963  724-438-9799      262 CONNELLSVILLE STREET
# 135784        VONS PHARMACY #1962  951-695-7273  29530 RANCHO CALIFORNIA ROAD
#
#                         City State  \
# 0                RIVER RIDGE    LA
# 1               PHILADELPHIA    PA
# 2                   EL CAJON    CA
# 3                 GIG HARBOR    WA
# 4                   Superior    WI
# ...                      ...   ...
# 135780  Feasterville Trevose    PA
# 135781               JAFFREY    NH
# 135782               ROANOKE    VA
# 135783             UNIONTOWN    PA
# 135784              Temecula    CA
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135780      https://www.acmemarkets.com/vaccinations/home                True
# 135781                            https://www.riteaid.com                True
# 135782  https://www.cvs.com/store-locator/details-dire...                True
# 135783                            https://www.riteaid.com                True
# 135784             https://www.vons.com/vaccinations/home                True
#
#         Walk-Ins Accepted  In Stock Last Updated   Latitude   Longitude
# 0                    True     False   2024-08-01  29.957522  -90.217062
# 1                    True     False   2024-08-01  40.080415  -75.171958
# 2                    True      True   2024-08-01  32.738217 -116.938327
# 3                   False     False   2024-08-01  47.302477 -122.581456
# 4                    True     False   2024-08-01  46.694518  -92.106958
# ...                   ...       ...          ...        ...         ...
# 135780               True     False   2024-08-01  40.147454  -74.999655
# 135781              False     False   2024-08-01  42.814691  -72.021353
# 135782               True     False   2024-08-01  37.224879  -80.011439
# 135783              False     False   2024-08-01  39.900490  -79.706902
# 135784               True     False   2024-08-01  33.505168 -117.147891
#
# [134709 rows x 12 columns]

# %%
novactype_duplicates_df = dropvaccinetypes1_df.drop_duplicates()
print(novactype_duplicates_df)
# Out:
#                         Location Name  Phone Number  \
# 0            CVS Pharmacy, Inc. #5340  504-737-6242
# 1            CVS Pharmacy, Inc. #2113  215-836-1323
# 2           CVS Pharmacy, Inc. #16504  619-315-0016
# 3                  Rite Aid #RA105255  253-851-6939
# 4                Walmart Inc #10-1447  715-392-9520
# ...                               ...           ...
# 135748       CVS Pharmacy, Inc. #5773  718-424-2846
# 135752  Publix Super Markets Inc. #17  803-407-0436
# 135761       CVS Pharmacy, Inc. #3607  954-432-6804
# 135765             Rite Aid #RA105326  503-698-8446
# 135781             Rite Aid #RA101653  603-532-6955
#
#                    Street Address            City State  \
# 0            9643-B JEFFERSON HWY     RIVER RIDGE    LA
# 1           1600 WADSWORTH AVENUE    PHILADELPHIA    PA
# 2                 2911 JAMACHA RD        EL CAJON    CA
# 3       4818 POINT FOSDICK DR.,NW      GIG HARBOR    WA
# 4                  3705 Tower Ave        Superior    WI
# ...                           ...             ...   ...
# 135748           69-80 GRAND AVE.         MASPETH    NY
# 135752      7320 Broad River Road            Irmo    SC
# 135761           11100 PINES BLVD  PEMBROKE PINES    FL
# 135765    12002 SE SUNNYSIDE ROAD       CLACKAMAS    OR
# 135781     14 PETERBOROUGH STREET         JAFFREY    NH
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135748  https://www.cvs.com/store-locator/details-dire...                True
# 135752  https://www.publix.com/pharmacy/pharmacy-servi...                True
# 135761  https://www.cvs.com/store-locator/details-dire...                True
# 135765                            https://www.riteaid.com                True
# 135781                            https://www.riteaid.com                True
#
#         Walk-Ins Accepted  In Stock Last Updated   Latitude   Longitude
# 0                    True     False   2024-08-01  29.957522  -90.217062
# 1                    True     False   2024-08-01  40.080415  -75.171958
# 2                    True      True   2024-08-01  32.738217 -116.938327
# 3                   False     False   2024-08-01  47.302477 -122.581456
# 4                    True     False   2024-08-01  46.694518  -92.106958
# ...                   ...       ...          ...        ...         ...
# 135748               True      True   2024-08-01  40.727200  -73.892748
# 135752               True      True   2024-08-01  34.096845  -81.157418
# 135761               True      True   2024-08-01  26.007142  -80.294594
# 135765              False     False   2024-08-01  45.429494 -122.540564
# 135781              False     False   2024-08-01  42.814691  -72.021353
#
# [31922 rows x 12 columns]

# %%
novactype_duplicates_df.head()
# Out:
#                Location Name  Phone Number             Street Address  \
# 0   CVS Pharmacy, Inc. #5340  504-737-6242       9643-B JEFFERSON HWY
# 1   CVS Pharmacy, Inc. #2113  215-836-1323      1600 WADSWORTH AVENUE
# 2  CVS Pharmacy, Inc. #16504  619-315-0016            2911 JAMACHA RD
# 3         Rite Aid #RA105255  253-851-6939  4818 POINT FOSDICK DR.,NW
# 4       Walmart Inc #10-1447  715-392-9520             3705 Tower Ave
#
#            City State                                            Website  \
# 0   RIVER RIDGE    LA  https://www.cvs.com/store-locator/details-dire...
# 1  PHILADELPHIA    PA  https://www.cvs.com/store-locator/details-dire...
# 2      EL CAJON    CA  https://www.cvs.com/store-locator/details-dire...
# 3    GIG HARBOR    WA                            https://www.riteaid.com
# 4      Superior    WI                 https://www.walmart.com/store/1447
#
#    Insurance Accepted  Walk-Ins Accepted  In Stock Last Updated   Latitude  \
# 0                True               True     False   2024-08-01  29.957522
# 1                True               True     False   2024-08-01  40.080415
# 2                True               True      True   2024-08-01  32.738217
# 3                True              False     False   2024-08-01  47.302477
# 4                True               True     False   2024-08-01  46.694518
#
#     Longitude
# 0  -90.217062
# 1  -75.171958
# 2 -116.938327
# 3 -122.581456
# 4  -92.106958

# %%
novactypestock_df = novactype_duplicates_df.drop(columns=['In Stock'])
print(novactypestock_df)
# Out:
#                         Location Name  Phone Number  \
# 0            CVS Pharmacy, Inc. #5340  504-737-6242
# 1            CVS Pharmacy, Inc. #2113  215-836-1323
# 2           CVS Pharmacy, Inc. #16504  619-315-0016
# 3                  Rite Aid #RA105255  253-851-6939
# 4                Walmart Inc #10-1447  715-392-9520
# ...                               ...           ...
# 135748       CVS Pharmacy, Inc. #5773  718-424-2846
# 135752  Publix Super Markets Inc. #17  803-407-0436
# 135761       CVS Pharmacy, Inc. #3607  954-432-6804
# 135765             Rite Aid #RA105326  503-698-8446
# 135781             Rite Aid #RA101653  603-532-6955
#
#                    Street Address            City State  \
# 0            9643-B JEFFERSON HWY     RIVER RIDGE    LA
# 1           1600 WADSWORTH AVENUE    PHILADELPHIA    PA
# 2                 2911 JAMACHA RD        EL CAJON    CA
# 3       4818 POINT FOSDICK DR.,NW      GIG HARBOR    WA
# 4                  3705 Tower Ave        Superior    WI
# ...                           ...             ...   ...
# 135748           69-80 GRAND AVE.         MASPETH    NY
# 135752      7320 Broad River Road            Irmo    SC
# 135761           11100 PINES BLVD  PEMBROKE PINES    FL
# 135765    12002 SE SUNNYSIDE ROAD       CLACKAMAS    OR
# 135781     14 PETERBOROUGH STREET         JAFFREY    NH
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135748  https://www.cvs.com/store-locator/details-dire...                True
# 135752  https://www.publix.com/pharmacy/pharmacy-servi...                True
# 135761  https://www.cvs.com/store-locator/details-dire...                True
# 135765                            https://www.riteaid.com                True
# 135781                            https://www.riteaid.com                True
#
#         Walk-Ins Accepted Last Updated   Latitude   Longitude
# 0                    True   2024-08-01  29.957522  -90.217062
# 1                    True   2024-08-01  40.080415  -75.171958
# 2                    True   2024-08-01  32.738217 -116.938327
# 3                   False   2024-08-01  47.302477 -122.581456
# 4                    True   2024-08-01  46.694518  -92.106958
# ...                   ...          ...        ...         ...
# 135748               True   2024-08-01  40.727200  -73.892748
# 135752               True   2024-08-01  34.096845  -81.157418
# 135761               True   2024-08-01  26.007142  -80.294594
# 135765              False   2024-08-01  45.429494 -122.540564
# 135781              False   2024-08-01  42.814691  -72.021353
#
# [31922 rows x 11 columns]

# %%
#remove in stock duplicates
novactypestockduplicate_df = novactypestock_df.drop_duplicates()
print(novactypestockduplicate_df)
# Out:
#                     Location Name  Phone Number             Street Address  \
# 0        CVS Pharmacy, Inc. #5340  504-737-6242       9643-B JEFFERSON HWY
# 1        CVS Pharmacy, Inc. #2113  215-836-1323      1600 WADSWORTH AVENUE
# 2       CVS Pharmacy, Inc. #16504  619-315-0016            2911 JAMACHA RD
# 3              Rite Aid #RA105255  253-851-6939  4818 POINT FOSDICK DR.,NW
# 4            Walmart Inc #10-1447  715-392-9520             3705 Tower Ave
# ...                           ...           ...                        ...
# 135309         Rite Aid #RA104695  586-463-8661     28350 SOUTH RIVER ROAD
# 135452         Rite Aid #RA107884  717-245-0116              320 YORK ROAD
# 135536         Rite Aid #RA105513  310-831-9167    501 SOUTH GAFFEY STREET
# 135765         Rite Aid #RA105326  503-698-8446    12002 SE SUNNYSIDE ROAD
# 135781         Rite Aid #RA101653  603-532-6955     14 PETERBOROUGH STREET
#
#                      City State  \
# 0             RIVER RIDGE    LA
# 1            PHILADELPHIA    PA
# 2                EL CAJON    CA
# 3              GIG HARBOR    WA
# 4                Superior    WI
# ...                   ...   ...
# 135309  HARRISON TOWNSHIP    MI
# 135452           CARLISLE    PA
# 135536          SAN PEDRO    CA
# 135765          CLACKAMAS    OR
# 135781            JAFFREY    NH
#
#                                                   Website  Insurance Accepted  \
# 0       https://www.cvs.com/store-locator/details-dire...                True
# 1       https://www.cvs.com/store-locator/details-dire...                True
# 2       https://www.cvs.com/store-locator/details-dire...                True
# 3                                 https://www.riteaid.com                True
# 4                      https://www.walmart.com/store/1447                True
# ...                                                   ...                 ...
# 135309                            https://www.riteaid.com                True
# 135452                            https://www.riteaid.com                True
# 135536                            https://www.riteaid.com                True
# 135765                            https://www.riteaid.com                True
# 135781                            https://www.riteaid.com                True
#
#         Walk-Ins Accepted Last Updated   Latitude   Longitude
# 0                    True   2024-08-01  29.957522  -90.217062
# 1                    True   2024-08-01  40.080415  -75.171958
# 2                    True   2024-08-01  32.738217 -116.938327
# 3                   False   2024-08-01  47.302477 -122.581456
# 4                    True   2024-08-01  46.694518  -92.106958
# ...                   ...          ...        ...         ...
# 135309              False   2024-08-01  42.589882  -82.827245
# 135452              False   2024-08-01  40.191357  -77.161413
# 135536              False   2024-08-01  33.739342 -118.293315
# 135765              False   2024-08-01  45.429494 -122.540564
# 135781              False   2024-08-01  42.814691  -72.021353
#
# [20523 rows x 11 columns]

# %%
#Save DataFrame to a csv
novactypestockduplicate_df.to_csv("novactypestock.csv")
# This is the final CSV file as of Nov 25, 2024, ~ 9 pm PST.

# %%
novactypestockduplicate_df.columns
# Out:
# Index(['Location Name', 'Phone Number', 'Street Address', 'City', 'State',
#        'Website', 'Insurance Accepted', 'Walk-Ins Accepted', 'Last Updated',
#        'Latitude', 'Longitude'],
#       dtype='object')

# %%
def get_zipcode_from_coordinates(latitude, longitude):

    api_key = "YOUR_GOOGLE_MAPS_API_KEY"  # Replace with your actual API key

    url = f"https://maps.googleapis.com/maps/api/geocode/json?latlng={latitude},{longitude}&key={api_key}"

    response = requests.get(url)

    data = response.json()

    

    if data['status'] == 'OK':

        zip_code = data['results'][0]['address_components'][0]['short_name']  # Access the zip code from the response

        return zip_code

    else:

        return None

# %%
# Initialize geolocator
geolocator = Nominatim(user_agent="my_geocoder")

def get_zipcode(lat, lon):
    try:
        location = geolocator.reverse((lat, lon), exactly_one=True)
        return location.raw['address'].get('postcode', None)
    except GeocoderTimedOut:
        return get_zipcode(lat, lon)  # Retry on timeout
    except Exception as e:
        return None


# Apply the function to each row
df['Zipcode'] = novactypestockduplicate_df.apply(lambda row: get_zipcode(row['Latitude'], row['Longitude']), axis=1)
print(df)
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connection.py:464, in HTTPConnection.getresponse(self)
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#
# File ~/anaconda3/envs/dev/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1374 try:
# -> 1375     response.begin()
#    1376 except ConnectionError:
#
# File ~/anaconda3/envs/dev/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#
# File ~/anaconda3/envs/dev/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#
# File ~/anaconda3/envs/dev/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     704 try:
# --> 705     return self._sock.recv_into(b)
#     706 except timeout:
#
# File ~/anaconda3/envs/dev/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1162 if buffer is not None:
# -> 1163     return self._sslobj.read(len, buffer)
#    1164 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/requests/adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:873, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     870     log.warning(
#     871         "Retrying (%r) after connection broken by '%r': %s", retries, err, url
#     872     )
# --> 873     return self.urlopen(
#     874         method,
#     875         url,
#     876         body,
#     877         headers,
#     878         retries,
#     879         redirect,
#     880         assert_same_host,
#     881         timeout=timeout,
#     882         pool_timeout=pool_timeout,
#     883         release_conn=release_conn,
#     884         chunked=chunked,
#     885         body_pos=body_pos,
#     886         preload_content=preload_content,
#     887         decode_content=decode_content,
#     888         **response_kw,
#     889     )
#     891 # Handle redirect?
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=28.659544&lon=-81.418369&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/geopy/adapters.py:482, in RequestsAdapter._request(self, url, timeout, headers)
#     481 try:
# --> 482     resp = self.session.get(url, timeout=timeout, headers=headers)
#     483 except Exception as error:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/requests/adapters.py:622, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     620         raise SSLError(e, request=request)
# --> 622     raise ConnectionError(e, request=request)
#     624 except ClosedPoolError as e:
#
# ConnectionError: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=28.659544&lon=-81.418369&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# GeocoderUnavailable                       Traceback (most recent call last)
# Cell In[28], line 6, in get_zipcode(lat, lon)
#       5 try:
# ----> 6     location = geolocator.reverse((lat, lon), exactly_one=True)
#       7     return location.raw['address'].get('postcode', None)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/geopy/geocoders/nominatim.py:372, in Nominatim.reverse(self, query, exactly_one, timeout, language, addressdetails, zoom, namedetails)
#     371 callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 372 return self._call_geocoder(url, callback, timeout=timeout)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/geopy/geocoders/base.py:368, in Geocoder._call_geocoder(self, url, callback, timeout, is_json, headers)
#     367 if is_json:
# --> 368     result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/geopy/adapters.py:472, in RequestsAdapter.get_json(self, url, timeout, headers)
#     471 def get_json(self, url, *, timeout, headers):
# --> 472     resp = self._request(url, timeout=timeout, headers=headers)
#     473     try:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/geopy/adapters.py:494, in RequestsAdapter._request(self, url, timeout, headers)
#     493     else:
# --> 494         raise GeocoderUnavailable(message)
#     495 elif isinstance(error, requests.Timeout):
#
# GeocoderUnavailable: HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Max retries exceeded with url: /reverse?lat=28.659544&lon=-81.418369&format=json&addressdetails=1 (Caused by ReadTimeoutError("HTTPSConnectionPool(host='nominatim.openstreetmap.org', port=443): Read timed out. (read timeout=1)"))
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 15
#      11         return None
#      14 # Apply the function to each row
# ---> 15 df['Zipcode'] = novactypestockduplicate_df.apply(lambda row: get_zipcode(row['Latitude'], row['Longitude']), axis=1)
#      16 print(df)
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/frame.py:10374, in DataFrame.apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10360 from pandas.core.apply import frame_apply
#   10362 op = frame_apply(
#   10363     self,
#   10364     func=func,
#    (...)
#   10372     kwargs=kwargs,
#   10373 )
# > 10374 return op.apply().__finalize__(self, method="apply")
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/apply.py:916, in FrameApply.apply(self)
#     913 elif self.raw:
#     914     return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
# --> 916 return self.apply_standard()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/apply.py:1063, in FrameApply.apply_standard(self)
#    1061 def apply_standard(self):
#    1062     if self.engine == "python":
# -> 1063         results, res_index = self.apply_series_generator()
#    1064     else:
#    1065         results, res_index = self.apply_series_numba()
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/pandas/core/apply.py:1081, in FrameApply.apply_series_generator(self)
#    1078 with option_context("mode.chained_assignment", None):
#    1079     for i, v in enumerate(series_gen):
#    1080         # ignore SettingWithCopy here in case the user mutates
# -> 1081         results[i] = self.func(v, *self.args, **self.kwargs)
#    1082         if isinstance(results[i], ABCSeries):
#    1083             # If we have a view on v, we need to make a copy because
#    1084             #  series_generator will swap out the underlying data
#    1085             results[i] = results[i].copy(deep=False)
#
# Cell In[28], line 15, in <lambda>(row)
#      11         return None
#      14 # Apply the function to each row
# ---> 15 df['Zipcode'] = novactypestockduplicate_df.apply(lambda row: get_zipcode(row['Latitude'], row['Longitude']), axis=1)
#      16 print(df)
#
# Cell In[28], line 8, in get_zipcode(lat, lon)
#       6     location = geolocator.reverse((lat, lon), exactly_one=True)
#       7     return location.raw['address'].get('postcode', None)
# ----> 8 except GeocoderTimedOut:
#       9     return get_zipcode(lat, lon)  # Retry on timeout
#      10 except Exception as e:
#
# NameError: name 'GeocoderTimedOut' is not defined

# %%
novactypestockduplicate_df.columns

# %% [markdown]
# ## Storing of Data in MongoDB, needs to be updated by Rowan

# %% [markdown]
# In the terminal, import data from csv using the following code:
# mongoImport --type csv -d vaccines_db -c vaccine_providers --headerline --drop Vaccine Providers.csv

# %%
# Module used to connect Python with MongoDB
from pymongo import MongoClient

# %%
# The default port used by MongoDB is 27017
# https://docs.mongodb.com/manual/reference/default-mongodb-port/
mongo = MongoClient(port=27017)

# Define the 'vaccines_db' database in Mongo
db = mongo.vaccines_db

# Declare the collection
providers = db.vaccine_providers

# %%
#Check that the data has been stored by making a query from the collection
location = providers.find()

print(location[0])
